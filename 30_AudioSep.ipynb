# %% [markdown]
# <a href="https://colab.research.google.com/github/peisuke/generative_ai_notebooks/blob/main/30_AudioSep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Audio-AGI/AudioSep.git
# %cd AudioSep
# Out:
# Cloning into 'AudioSep'...
# remote: Enumerating objects: 245, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 245 (delta 38), reused 37 (delta 29), pack-reused 174
# Receiving objects: 100% (245/245), 16.53 MiB | 7.07 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# /content/AudioSep

# %%
# !pip install torchlibrosa==0.1.0 gradio==3.47.1 gdown lightning transformers==4.28.1 ftfy braceexpand webdataset soundfile wget h5py
# Out:
# Collecting torchlibrosa==0.1.0
#   Downloading torchlibrosa-0.1.0-py3-none-any.whl (11 kB)
# Collecting gradio==3.47.1
#   Downloading gradio-3.47.1-py3-none-any.whl (20.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 40.6 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Collecting lightning
#   Downloading lightning-2.1.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.5 MB/s eta 0:00:00
# Collecting transformers==4.28.1
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 34.3 MB/s eta 0:00:00
# Collecting ftfy
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 5.8 MB/s eta 0:00:00
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting webdataset
#   Downloading webdataset-0.2.86-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchlibrosa==0.1.0) (1.23.5)
# Requirement already satisfied: librosa>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchlibrosa==0.1.0) (0.10.1)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.47.1)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (4.2.2)
# Collecting fastapi (from gradio==3.47.1)
#   Downloading fastapi-0.105.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 12.0 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==3.47.1)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.6.0 (from gradio==3.47.1)
#   Downloading gradio_client-0.6.0-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 33.6 MB/s eta 0:00:00
# Collecting httpx (from gradio==3.47.1)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (0.19.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (3.7.1)
# Collecting orjson~=3.0 (from gradio==3.47.1)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (9.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (1.10.13)
# Collecting pydub (from gradio==3.47.1)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio==3.47.1)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (2.31.0)
# Collecting semantic-version~=2.0 (from gradio==3.47.1)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (4.5.0)
# Collecting uvicorn>=0.14.0 (from gradio==3.47.1)
#   Downloading uvicorn-0.24.0.post1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 5.3 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0 (from gradio==3.47.1)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.1) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.1) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.28.1)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.1) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.6.0->gradio==3.47.1) (2023.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Collecting lightning-utilities<2.0,>=0.8.0 (from lightning)
#   Downloading lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: torch<4.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (2.1.0+cu118)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning)
#   Downloading torchmetrics-1.2.1-py3-none-any.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 45.3 MB/s eta 0:00:00
# Collecting pytorch-lightning (from lightning)
#   Downloading pytorch_lightning-2.1.2-py3-none-any.whl (776 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 64.7 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.12)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.16.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.47.1) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.47.1) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.47.1) (0.12.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec->gradio-client==0.6.0->gradio==3.47.1) (3.9.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (0.58.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities<2.0,>=0.8.0->lightning) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==3.47.1) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (2023.11.17)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.12.0->lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.12.0->lightning) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.12.0->lightning) (2.1.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.47.1) (8.1.7)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio==3.47.1)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.47.1) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio==3.47.1)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.4 MB/s eta 0:00:00
# Collecting typing-extensions~=4.0 (from gradio==3.47.1)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting httpcore==1.* (from httpx->gradio==3.47.1)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.47.1) (1.3.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (1.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (4.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio==3.47.1) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.47.1) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.47.1) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.47.1) (0.13.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.8.0->torchlibrosa==0.1.0) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa>=0.8.0->torchlibrosa==0.1.0) (4.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa>=0.8.0->torchlibrosa==0.1.0) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<4.0,>=1.12.0->lightning) (1.3.0)
# Building wheels for collected packages: wget, ffmpy
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=a97f784ba0ff97e8c381e3f295d3eeb7e1733be2747486bd4cbaf89c49a44a0e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=448531613a330b63cab244578d0c18ac6c7c68e704fb4166e4c2bbc4a6aa123a
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built wget ffmpy
# Installing collected packages: wget, tokenizers, pydub, ffmpy, braceexpand, websockets, webdataset, typing-extensions, semantic-version, python-multipart, orjson, h11, ftfy, aiofiles, uvicorn, starlette, lightning-utilities, httpcore, transformers, torchmetrics, httpx, fastapi, torchlibrosa, pytorch-lightning, gradio-client, lightning, gradio
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 braceexpand-0.1.7 fastapi-0.105.0 ffmpy-0.3.1 ftfy-6.1.3 gradio-3.47.1 gradio-client-0.6.0 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 lightning-2.1.2 lightning-utilities-0.10.0 orjson-3.9.10 pydub-0.25.1 python-multipart-0.0.6 pytorch-lightning-2.1.2 semantic-version-2.10.0 starlette-0.27.0 tokenizers-0.13.3 torchlibrosa-0.1.0 torchmetrics-1.2.1 transformers-4.28.1 typing-extensions-4.9.0 uvicorn-0.24.0.post1 webdataset-0.2.86 websockets-11.0.3 wget-3.2

# %%
# !mkdir -p checkpoint
# !wget "https://huggingface.co/spaces/badayvedat/AudioSep/resolve/main/checkpoint/audiosep_base_4M_steps.ckpt" \
    -O checkpoint/audiosep_base_4M_steps.ckpt
# !wget "https://huggingface.co/spaces/badayvedat/AudioSep/resolve/main/checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt" \
    -O checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt
# Out:
# --2023-12-14 10:41:22--  https://huggingface.co/spaces/badayvedat/AudioSep/resolve/main/checkpoint/audiosep_base_4M_steps.ckpt
# Resolving huggingface.co (huggingface.co)... 54.230.18.95, 54.230.18.84, 54.230.18.110, ...
# Connecting to huggingface.co (huggingface.co)|54.230.18.95|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/25/5f/255f11fd2743cf4de0c72f1eba5cdf82634d22af3ce4fcc5b16dbd7b7feddaca/f8cda01bfd0ebd141eef45d41db7a3ada23a56568465840d3cff04b8010ce82c?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27audiosep_base_4M_steps.ckpt%3B+filename%3D%22audiosep_base_4M_steps.ckpt%22%3B&Expires=1702809682&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=aAXA3RalYiLJ6jMuuiAitc%7Ebup%7EJM1RDQNpCHo-WiSqazT6ZmTttkVByyzQHb39zGqCIY1q2h3dC%7EmIRun6PwYcCEtOiB6RyLdWWnxh5d0tWyLGcKkIeI2N3K-DxpxD5oHR5ph-SFcvriW7iYI8dlXmMZ1nhQ%7EM-3lZ5uf2mvbfx%7EhgeZ9morHPfsJc7BzlPhoHmsSt-NS9Sno%7EGldrLA4bzL5%7EI4ocDlm1Oo5H3VJuiuHrfArr3sWijVEBDZj43yHl51W3Gr52PhyMwZoeYe1O60j3sIt4GER8z85IngKxd1MWtQj42p4m2WoRz9QlorHMpWOsQ%7EkPKzvw7%7E1YgNw__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-12-14 10:41:22--  https://cdn-lfs.huggingface.co/repos/25/5f/255f11fd2743cf4de0c72f1eba5cdf82634d22af3ce4fcc5b16dbd7b7feddaca/f8cda01bfd0ebd141eef45d41db7a3ada23a56568465840d3cff04b8010ce82c?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27audiosep_base_4M_steps.ckpt%3B+filename%3D%22audiosep_base_4M_steps.ckpt%22%3B&Expires=1702809682&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=aAXA3RalYiLJ6jMuuiAitc%7Ebup%7EJM1RDQNpCHo-WiSqazT6ZmTttkVByyzQHb39zGqCIY1q2h3dC%7EmIRun6PwYcCEtOiB6RyLdWWnxh5d0tWyLGcKkIeI2N3K-DxpxD5oHR5ph-SFcvriW7iYI8dlXmMZ1nhQ%7EM-3lZ5uf2mvbfx%7EhgeZ9morHPfsJc7BzlPhoHmsSt-NS9Sno%7EGldrLA4bzL5%7EI4ocDlm1Oo5H3VJuiuHrfArr3sWijVEBDZj43yHl51W3Gr52PhyMwZoeYe1O60j3sIt4GER8z85IngKxd1MWtQj42p4m2WoRz9QlorHMpWOsQ%7EkPKzvw7%7E1YgNw__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.159.227.69, 108.159.227.71, 108.159.227.123, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.159.227.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1264844076 (1.2G) [application/zip]
# Saving to: ‘checkpoint/audiosep_base_4M_steps.ckpt’
#
# checkpoint/audiosep 100%[===================>]   1.18G  44.7MB/s    in 31s
#
# 2023-12-14 10:41:54 (38.7 MB/s) - ‘checkpoint/audiosep_base_4M_steps.ckpt’ saved [1264844076/1264844076]
#
# --2023-12-14 10:41:54--  https://huggingface.co/spaces/badayvedat/AudioSep/resolve/main/checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt
# Resolving huggingface.co (huggingface.co)... 54.230.18.95, 54.230.18.84, 54.230.18.85, ...
# Connecting to huggingface.co (huggingface.co)|54.230.18.95|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/25/5f/255f11fd2743cf4de0c72f1eba5cdf82634d22af3ce4fcc5b16dbd7b7feddaca/51c68f12f9d7ea25fdaaccf741ec7f81e93ee594455410f3bca4f47f88d8e006?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27music_speech_audioset_epoch_15_esc_89.98.pt%3B+filename%3D%22music_speech_audioset_epoch_15_esc_89.98.pt%22%3B&Expires=1702809714&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=cDoWxL7QKIDInBO3cc7V2-SF83ABGYlaLtzvEQ6mbA5VBn5U1aQIFb0cLF5nGSnwno64MO0PWJXa09xwiTmlc%7E3j8P502lDNMk6zg%7EjnPhtIUcLcv48QaPt1is6V7j7ZDxlmRigpx7PLCagjUat-CMAxqkTVpyD06IkMGlkaVXXOzaQz3HFSh74an7wJlDZQS9x5GbIRG21PPI6hTuZvfmXIlMWMrHefzUpH9lCzEu%7E90Qrui-%7EsXyaxoV3R1eBeSMjz7VFlnYGwoV5LpySrOxaghS9NQY2aUgfwe86AlDdKjb4pjOpG%7EnlowE7aTMykjktFFH4JHmQvsUQDJn3kxw__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-12-14 10:41:54--  https://cdn-lfs.huggingface.co/repos/25/5f/255f11fd2743cf4de0c72f1eba5cdf82634d22af3ce4fcc5b16dbd7b7feddaca/51c68f12f9d7ea25fdaaccf741ec7f81e93ee594455410f3bca4f47f88d8e006?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27music_speech_audioset_epoch_15_esc_89.98.pt%3B+filename%3D%22music_speech_audioset_epoch_15_esc_89.98.pt%22%3B&Expires=1702809714&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=cDoWxL7QKIDInBO3cc7V2-SF83ABGYlaLtzvEQ6mbA5VBn5U1aQIFb0cLF5nGSnwno64MO0PWJXa09xwiTmlc%7E3j8P502lDNMk6zg%7EjnPhtIUcLcv48QaPt1is6V7j7ZDxlmRigpx7PLCagjUat-CMAxqkTVpyD06IkMGlkaVXXOzaQz3HFSh74an7wJlDZQS9x5GbIRG21PPI6hTuZvfmXIlMWMrHefzUpH9lCzEu%7E90Qrui-%7EsXyaxoV3R1eBeSMjz7VFlnYGwoV5LpySrOxaghS9NQY2aUgfwe86AlDdKjb4pjOpG%7EnlowE7aTMykjktFFH4JHmQvsUQDJn3kxw__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.159.227.123, 108.159.227.71, 108.159.227.69, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.159.227.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2352471003 (2.2G) [application/zip]
# Saving to: ‘checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt’
#
# checkpoint/music_sp 100%[===================>]   2.19G  48.4MB/s    in 37s
#
# 2023-12-14 10:42:31 (61.3 MB/s) - ‘checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt’ saved [2352471003/2352471003]

# %%
import torch
from pipeline import build_audiosep, inference

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = build_audiosep(
      config_yaml='config/audiosep_base.yaml',
      checkpoint_path="checkpoint/audiosep_base_4M_steps.ckpt",
      device=device)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Load AudioSep model from [checkpoint/audiosep_base_4M_steps.ckpt]

# %%
# !wget "https://audio-agi.github.io/Separate-Anything-You-Describe/demos/exp31_water drops_mixture.wav"
# Out:
# --2023-12-14 10:47:17--  https://audio-agi.github.io/Separate-Anything-You-Describe/demos/exp31_water%20drops_mixture.wav
# Resolving audio-agi.github.io (audio-agi.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to audio-agi.github.io (audio-agi.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 320044 (313K) [audio/wav]
# Saving to: ‘exp31_water drops_mixture.wav’
#
# exp31_water drops_m 100%[===================>] 312.54K  --.-KB/s    in 0.03s
#
# 2023-12-14 10:47:17 (9.03 MB/s) - ‘exp31_water drops_mixture.wav’ saved [320044/320044]

# %%
audio_file = 'exp31_water drops_mixture.wav'
text = 'water drops'
output_file='separated_audio.wav'

# AudioSep processes the audio at 32 kHz sampling rate
inference(model, audio_file, text, output_file, device)
# Out:
# Separate audio from [exp31_water drops_mixture.wav] with textual query [water drops]
# Write separated audio to [separated_audio.wav]

# %%
from IPython.display import Audio
Audio(output_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_file = "/content/drive/MyDrive/AI/AudioSep/trombone_guitar_clip.wav"
text = 'trombone melody without classic guitar'
output_file='separated_audio_trombone.wav'
inference(model, audio_file, text, output_file, device)
# Out:
# Separate audio from [/content/drive/MyDrive/AI/AudioSep/trombone_guitar_clip.wav] with textual query [trombone melody without classic guitar]
# Write separated audio to [separated_audio_trombone.wav]

# %%
from IPython.display import Audio
Audio(output_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_file = "/content/drive/MyDrive/AI/AudioSep/trombone_guitar_clip.wav"
text = 'classic guitar'
output_file='separated_audio_guitar.wav'
inference(model, audio_file, text, output_file, device)
# Out:
# Separate audio from [/content/drive/MyDrive/AI/AudioSep/trombone_guitar_clip.wav] with textual query [classic guitar]
# Write separated audio to [separated_audio_guitar.wav]

# %%
from IPython.display import Audio
Audio(output_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
